# %% [markdown]
# https://www.kaggle.com/code/eliotbarr/stacking-test-sklearn-xgboost-catboost-lightgbm/comments

# %% [markdown]
# # 목적:
# to use **historical loan application data** to predict whether or not an applicant will be able to repay a loan.
#
# For each SK_ID_CURR in the test set, you must predict a **probability for the TARGET variable. **

# %% [markdown]
# 1. application_train/application_test (주 대출 신청 데이터): 이 데이터 세트에는 Home Credit에서 대출 신청 시 제공된 각 대출에 대한 정보가 포함되어 있습니다. 각 대출은 SK_ID_CURR이라는 고유 번호로 식별됩니다. 대출 신청 데이터에는 대출이 상환되었는지(TARGET 값 0), 상환되지 않았는지(TARGET 값 1)를 나타내는 TARGET 필드가 포함되어 있습니다.
#
# 2. bureau (타 금융 기관 대출 정보): 이 데이터는 고객이 다른 금융 기관에서 받은 이전 대출에 관한 정보를 담고 있습니다. 이전 대출 각각이 자체 행을 가지고 있으며, 한 대출 신청 데이터는 여러 이전 대출 정보를 가질 수 있습니다.
#
# 3. bureau_balance (타 금융 기관 대출 잔액 월별 데이터): bureau에 기록된 이전 대출의 월별 데이터입니다. 각 행은 이전 대출의 한 달치를 나타내며, 하나의 이전 대출에 대해 여러 행이 있을 수 있습니다.
#
# 4. previous_application (이전 대출 신청 데이터): Home Credit에서 고객이 이전에 신청한 대출에 대한 정보입니다. 현재 대출 신청 데이터에 포함된 고객이 이전에 신청한 대출 각각에 대해 한 행씩 있으며, SK_ID_PREV로 식별됩니다.
#
# 5. POS_CASH_BALANCE (판매점 현금 대출 월별 데이터): Home Credit과의 이전 판매점 현금 대출에 대한 월별 데이터입니다. 각 행은 이전 대출의 한 달치를 나타내며, 하나의 대출에 대해 여러 행이 있을 수 있습니다.
#
# 6. credit_card_balance (신용카드 잔액 월별 데이터): 고객이 Home Credit과 가졌던 이전 신용카드의 월별 잔액 데이터입니다. 각 행은 한 달치 신용카드 잔액을 나타내며, 하나의 신용카드 계좌에 대해 여러 행이 있을 수 있습니다.
#
# 7. installments_payment (대출 상환 내역): Home Credit에서의 이전 대출에 대한 상환 내역입니다. 상환된 각각의 지불과 누락된 각각의 지불에 대해 한 행씩 있습니다.
#
# 즉, Home Credit에서 대출을 신청한 고객들의 신청 정보, 이전 대출 상환 내역, 그리고 다른 금융 기관에서의 대출 내역을 통해 Home Credit이 고객의 대출 상환 능력을 평가하고 예측하기

# %% [markdown]
# * 진짜 양성 비율(TPR): 실제로 양성인 데이터 중에서 모델이 양성으로 올바르게 예측한 데이터의 비율입니다. 예를 들어, 실제 스팸 이메일 100개 중 모델이 90개를 스팸으로 올바르게 예측했다면 TPR은 90%입니다.
# * 거짓 양성 비율(FPR): 실제로는 음성인 데이터 중에서 모델이 양성으로 잘못 예측한
# 데이터의 비율입니다. 예를 들어, 실제 스팸이 아닌 이메일 100개 중 모델이 10개를 스팸으로 잘못 예측했다면 FPR은 10%입니다.
#
# ROC AUC는 ROC 곡선 아래의 면적으로, 0에서 1 사이의 값을 가집니다. 이 값이 1에 가까울수록 모델의 성능이 뛰어나다는 것을 의미합니다. 즉, 모델이 진짜 양성을 양성으로, 진짜 음성을 음성으로 정확하게 분류할 확률이 높다는 것을 나타냅니다. 반면, AUC 값이 0.5에 가까우면 모델의 성능이 무작위 추측 수준임을 의미합니다.

# %%
from google.colab import drive

# %%
# !unzip '/content/drive/MyDrive/KUBIG/데이터분석 스터디/home-credit-default-risk.zip'
# Out:
# Archive:  /content/drive/MyDrive/KUBIG/데이터분석 스터디/home-credit-default-risk.zip
#   inflating: HomeCredit_columns_description.csv
#   inflating: POS_CASH_balance.csv
#   inflating: application_test.csv
#   inflating: application_train.csv
#   inflating: bureau.csv
#   inflating: bureau_balance.csv
#   inflating: credit_card_balance.csv
#   inflating: installments_payments.csv
#   inflating: previous_application.csv
#   inflating: sample_submission.csv

# %%
# !pip3 install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.3-cp310-cp310-manylinux2014_x86_64.whl (98.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.3

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from math import sqrt
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import gc

NFOLDS = 3
SEED = 0
NROWS = None

data = pd.read_csv('/content/application_train.csv')
test = pd.read_csv('/content/application_test.csv')
prev = pd.read_csv('/content/previous_application.csv')

categorical_feats = [
    f for f in data.columns if data[f].dtype == 'object'
]

for f_ in categorical_feats:
    data[f_], indexer = pd.factorize(data[f_])
    test[f_] = indexer.get_indexer(test[f_])

gc.enable()

y_train = data['TARGET']
del data['TARGET']

prev_cat_features = [
    f_ for f_ in prev.columns if prev[f_].dtype == 'object'
]
for f_ in prev_cat_features:
    prev[f_], _ = pd.factorize(prev[f_])

avg_prev = prev.groupby('SK_ID_CURR').mean()
cnt_prev = prev[['SK_ID_CURR', 'SK_ID_PREV']].groupby('SK_ID_CURR').count()
avg_prev['nb_app'] = cnt_prev['SK_ID_PREV']
del avg_prev['SK_ID_PREV']

x_train = data.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')
x_test = test.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')

x_train = x_train.fillna(0)
x_test= x_test.fillna(0)

ntrain = x_train.shape[0]
ntest = x_test.shape[0]

excluded_feats = ['SK_ID_CURR']
features = [f_ for f_ in x_train.columns if f_ not in excluded_feats]

x_train = x_train[features]
x_test = x_test[features]

kf = KFold(n_splits = NFOLDS, shuffle=True, random_state=SEED)

class SklearnWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_state'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]

class CatboostWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_seed'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]

class LightGBMWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['feature_fraction_seed'] = seed
        params['bagging_seed'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]


class XgbWrapper(object):
    def __init__(self, seed=0, params=None):
        self.param = params
        self.param['seed'] = seed
        self.nrounds = params.pop('nrounds', 250)

    def train(self, x_train, y_train):
        dtrain = xgb.DMatrix(x_train, label=y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)

    def predict(self, x):
        return self.gbdt.predict(xgb.DMatrix(x))


def get_oof(clf):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest,))
    oof_test_skf = np.empty((NFOLDS, ntest))

    for i, (train_index, test_index) in enumerate(kf.split(x_train)):
        x_tr = x_train.loc[train_index]
        y_tr = y_train.loc[train_index]
        x_te = x_train.loc[test_index]

        clf.train(x_tr, y_tr)

        oof_train[test_index] = clf.predict(x_te)
        oof_test_skf[i, :] = clf.predict(x_test)

    oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)


et_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.5,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

rf_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.2,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

xgb_params = {
    'seed': 0,
    'colsample_bytree': 0.7,
    'silent': 1,
    'subsample': 0.7,
    'learning_rate': 0.075,
    'objective': 'binary:logistic',
    'max_depth': 4,
    'num_parallel_tree': 1,
    'min_child_weight': 1,
    'nrounds': 200
}

catboost_params = {
    'iterations': 200,
    'learning_rate': 0.5,
    'depth': 3,
    'l2_leaf_reg': 40,
    'bootstrap_type': 'Bernoulli',
    'subsample': 0.7,
    'scale_pos_weight': 5,
    'eval_metric': 'AUC',
    'od_type': 'Iter',
    'allow_writing_files': False
}

lightgbm_params = {
    'n_estimators':200,
    'learning_rate':0.1,
    'num_leaves':123,
    'colsample_bytree':0.8,
    'subsample':0.9,
    'max_depth':15,
    'reg_alpha':0.1,
    'reg_lambda':0.1,
    'min_split_gain':0.01,
    'min_child_weight':2
}

xg = XgbWrapper(seed=SEED, params=xgb_params)
et = SklearnWrapper(clf=ExtraTreesClassifier, seed=SEED, params=et_params)
rf = SklearnWrapper(clf=RandomForestClassifier, seed=SEED, params=rf_params)
cb = CatboostWrapper(clf= CatBoostClassifier, seed = SEED, params=catboost_params)
lg = LightGBMWrapper(clf = LGBMClassifier, seed = SEED, params = lightgbm_params)

xg_oof_train, xg_oof_test = get_oof(xg)
et_oof_train, et_oof_test = get_oof(et)
rf_oof_train, rf_oof_test = get_oof(rf)
cb_oof_train, cb_oof_test = get_oof(cb)

print("XG-CV: {}".format(sqrt(mean_squared_error(y_train, xg_oof_train))))
print("ET-CV: {}".format(sqrt(mean_squared_error(y_train, et_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, rf_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, cb_oof_train))))

x_train = np.concatenate((xg_oof_train, et_oof_train, rf_oof_train, cb_oof_train), axis=1)
x_test = np.concatenate((xg_oof_test, et_oof_test, rf_oof_test, cb_oof_test), axis=1)

print("{},{}".format(x_train.shape, x_test.shape))

logistic_regression = LogisticRegression()
logistic_regression.fit(x_train,y_train)

test['TARGET'] = logistic_regression.predict_proba(x_test)[:,1]

test[['SK_ID_CURR', 'TARGET']].to_csv('first_submission.csv', index=False, float_format='%.8f')
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [21:02:28] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [21:03:05] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [21:03:37] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 0:	total: 218ms	remaining: 43.3s
# 1:	total: 337ms	remaining: 33.4s
# 2:	total: 437ms	remaining: 28.7s
# 3:	total: 565ms	remaining: 27.7s
# 4:	total: 636ms	remaining: 24.8s
# 5:	total: 699ms	remaining: 22.6s
# 6:	total: 756ms	remaining: 20.8s
# 7:	total: 809ms	remaining: 19.4s
# 8:	total: 877ms	remaining: 18.6s
# 9:	total: 941ms	remaining: 17.9s
# 10:	total: 996ms	remaining: 17.1s
# 11:	total: 1.07s	remaining: 16.8s
# 12:	total: 1.14s	remaining: 16.4s
# 13:	total: 1.2s	remaining: 15.9s
# 14:	total: 1.26s	remaining: 15.6s
# 15:	total: 1.32s	remaining: 15.2s
# 16:	total: 1.37s	remaining: 14.8s
# 17:	total: 1.43s	remaining: 14.4s
# 18:	total: 1.48s	remaining: 14.1s
# 19:	total: 1.54s	remaining: 13.8s
# 20:	total: 1.6s	remaining: 13.6s
# 21:	total: 1.65s	remaining: 13.3s
# 22:	total: 1.71s	remaining: 13.2s
# 23:	total: 1.76s	remaining: 12.9s
# 24:	total: 1.82s	remaining: 12.8s
# 25:	total: 1.88s	remaining: 12.6s
# 26:	total: 1.94s	remaining: 12.4s
# 27:	total: 2s	remaining: 12.3s
# 28:	total: 2.07s	remaining: 12.2s
# 29:	total: 2.13s	remaining: 12s
# 30:	total: 2.19s	remaining: 11.9s
# 31:	total: 2.25s	remaining: 11.8s
# 32:	total: 2.31s	remaining: 11.7s
# 33:	total: 2.37s	remaining: 11.5s
# 34:	total: 2.42s	remaining: 11.4s
# 35:	total: 2.48s	remaining: 11.3s
# 36:	total: 2.53s	remaining: 11.2s
# 37:	total: 2.59s	remaining: 11s
# 38:	total: 2.65s	remaining: 10.9s
# 39:	total: 2.71s	remaining: 10.8s
# 40:	total: 2.77s	remaining: 10.7s
# 41:	total: 2.82s	remaining: 10.6s
# 42:	total: 2.88s	remaining: 10.5s
# 43:	total: 2.95s	remaining: 10.5s
# 44:	total: 3.01s	remaining: 10.4s
# 45:	total: 3.06s	remaining: 10.3s
# 46:	total: 3.13s	remaining: 10.2s
# 47:	total: 3.19s	remaining: 10.1s
# 48:	total: 3.25s	remaining: 10s
# 49:	total: 3.31s	remaining: 9.93s
# 50:	total: 3.37s	remaining: 9.86s
# 51:	total: 3.43s	remaining: 9.77s
# 52:	total: 3.5s	remaining: 9.69s
# 53:	total: 3.55s	remaining: 9.61s
# 54:	total: 3.62s	remaining: 9.54s
# 55:	total: 3.68s	remaining: 9.46s
# 56:	total: 3.73s	remaining: 9.37s
# 57:	total: 3.79s	remaining: 9.28s
# 58:	total: 3.84s	remaining: 9.18s
# 59:	total: 3.9s	remaining: 9.1s
# 60:	total: 3.96s	remaining: 9.03s
# 61:	total: 4.03s	remaining: 8.96s
# 62:	total: 4.08s	remaining: 8.87s
# 63:	total: 4.15s	remaining: 8.82s
# 64:	total: 4.22s	remaining: 8.76s
# 65:	total: 4.28s	remaining: 8.69s
# 66:	total: 4.33s	remaining: 8.61s
# 67:	total: 4.39s	remaining: 8.53s
# 68:	total: 4.46s	remaining: 8.46s
# 69:	total: 4.51s	remaining: 8.38s
# 70:	total: 4.57s	remaining: 8.3s
# 71:	total: 4.62s	remaining: 8.22s
# 72:	total: 4.68s	remaining: 8.15s
# 73:	total: 4.75s	remaining: 8.08s
# 74:	total: 4.81s	remaining: 8.01s
# 75:	total: 4.87s	remaining: 7.94s
# 76:	total: 4.92s	remaining: 7.87s
# 77:	total: 4.98s	remaining: 7.79s
# 78:	total: 5.04s	remaining: 7.71s
# 79:	total: 5.09s	remaining: 7.63s
# 80:	total: 5.17s	remaining: 7.6s
# 81:	total: 5.23s	remaining: 7.52s
# 82:	total: 5.28s	remaining: 7.44s
# 83:	total: 5.34s	remaining: 7.37s
# 84:	total: 5.39s	remaining: 7.3s
# 85:	total: 5.45s	remaining: 7.22s
# 86:	total: 5.5s	remaining: 7.15s
# 87:	total: 5.57s	remaining: 7.09s
# 88:	total: 5.63s	remaining: 7.02s
# 89:	total: 5.68s	remaining: 6.95s
# 90:	total: 5.74s	remaining: 6.87s
# 91:	total: 5.8s	remaining: 6.81s
# 92:	total: 5.87s	remaining: 6.75s
# 93:	total: 5.92s	remaining: 6.68s
# 94:	total: 5.98s	remaining: 6.61s
# 95:	total: 6.03s	remaining: 6.54s
# 96:	total: 6.1s	remaining: 6.47s
# 97:	total: 6.16s	remaining: 6.42s
# 98:	total: 6.23s	remaining: 6.36s
# 99:	total: 6.32s	remaining: 6.32s
# 100:	total: 6.38s	remaining: 6.26s
# 101:	total: 6.44s	remaining: 6.19s
# 102:	total: 6.5s	remaining: 6.12s
# 103:	total: 6.56s	remaining: 6.06s
# 104:	total: 6.62s	remaining: 5.99s
# 105:	total: 6.67s	remaining: 5.92s
# 106:	total: 6.73s	remaining: 5.85s
# 107:	total: 6.79s	remaining: 5.78s
# 108:	total: 6.84s	remaining: 5.71s
# 109:	total: 6.9s	remaining: 5.64s
# 110:	total: 6.96s	remaining: 5.58s
# 111:	total: 7.01s	remaining: 5.51s
# 112:	total: 7.08s	remaining: 5.45s
# 113:	total: 7.14s	remaining: 5.38s
# 114:	total: 7.2s	remaining: 5.32s
# 115:	total: 7.27s	remaining: 5.26s
# 116:	total: 7.33s	remaining: 5.2s
# 117:	total: 7.39s	remaining: 5.13s
# 118:	total: 7.45s	remaining: 5.07s
# 119:	total: 7.51s	remaining: 5.01s
# 120:	total: 7.57s	remaining: 4.94s
# 121:	total: 7.63s	remaining: 4.88s
# 122:	total: 7.69s	remaining: 4.81s
# 123:	total: 7.74s	remaining: 4.74s
# 124:	total: 7.8s	remaining: 4.68s
# 125:	total: 7.86s	remaining: 4.62s
# 126:	total: 7.91s	remaining: 4.55s
# 127:	total: 7.98s	remaining: 4.49s
# 128:	total: 8.04s	remaining: 4.42s
# 129:	total: 8.09s	remaining: 4.36s
# 130:	total: 8.15s	remaining: 4.29s
# 131:	total: 8.22s	remaining: 4.24s
# 132:	total: 8.28s	remaining: 4.17s
# 133:	total: 8.34s	remaining: 4.11s
# 134:	total: 8.4s	remaining: 4.04s
# 135:	total: 8.46s	remaining: 3.98s
# 136:	total: 8.52s	remaining: 3.92s
# 137:	total: 8.58s	remaining: 3.85s
# 138:	total: 8.64s	remaining: 3.79s
# 139:	total: 8.71s	remaining: 3.73s
# 140:	total: 8.76s	remaining: 3.67s
# 141:	total: 8.82s	remaining: 3.6s
# 142:	total: 8.87s	remaining: 3.54s
# 143:	total: 8.93s	remaining: 3.47s
# 144:	total: 8.99s	remaining: 3.41s
# 145:	total: 9.05s	remaining: 3.35s
# 146:	total: 9.11s	remaining: 3.28s
# 147:	total: 9.17s	remaining: 3.22s
# 148:	total: 9.24s	remaining: 3.16s
# 149:	total: 9.3s	remaining: 3.1s
# 150:	total: 9.36s	remaining: 3.04s
# 151:	total: 9.41s	remaining: 2.97s
# 152:	total: 9.47s	remaining: 2.91s
# 153:	total: 9.53s	remaining: 2.85s
# 154:	total: 9.58s	remaining: 2.78s
# 155:	total: 9.65s	remaining: 2.72s
# 156:	total: 9.71s	remaining: 2.66s
# 157:	total: 9.77s	remaining: 2.6s
# 158:	total: 9.82s	remaining: 2.53s
# 159:	total: 9.88s	remaining: 2.47s
# 160:	total: 9.94s	remaining: 2.41s
# 161:	total: 9.99s	remaining: 2.34s
# 162:	total: 10.1s	remaining: 2.28s
# 163:	total: 10.1s	remaining: 2.22s
# 164:	total: 10.2s	remaining: 2.16s
# 165:	total: 10.3s	remaining: 2.1s
# 166:	total: 10.3s	remaining: 2.04s
# 167:	total: 10.4s	remaining: 1.99s
# 168:	total: 10.5s	remaining: 1.92s
# 169:	total: 10.6s	remaining: 1.86s
# 170:	total: 10.7s	remaining: 1.81s
# 171:	total: 10.7s	remaining: 1.75s
# 172:	total: 10.9s	remaining: 1.69s
# 173:	total: 11s	remaining: 1.64s
# 174:	total: 11.1s	remaining: 1.58s
# 175:	total: 11.2s	remaining: 1.52s
# 176:	total: 11.3s	remaining: 1.47s
# 177:	total: 11.4s	remaining: 1.41s
# 178:	total: 11.5s	remaining: 1.35s
# 179:	total: 11.7s	remaining: 1.29s
# 180:	total: 11.8s	remaining: 1.24s
# 181:	total: 11.9s	remaining: 1.18s
# 182:	total: 12s	remaining: 1.12s
# 183:	total: 12.1s	remaining: 1.05s
# 184:	total: 12.3s	remaining: 994ms
# 185:	total: 12.4s	remaining: 932ms
# 186:	total: 12.5s	remaining: 869ms
# 187:	total: 12.6s	remaining: 805ms
# 188:	total: 12.7s	remaining: 741ms
# 189:	total: 12.8s	remaining: 676ms
# 190:	total: 13s	remaining: 610ms
# 191:	total: 13s	remaining: 544ms
# 192:	total: 13.2s	remaining: 478ms
# 193:	total: 13.3s	remaining: 410ms
# 194:	total: 13.4s	remaining: 344ms
# 195:	total: 13.5s	remaining: 275ms
# 196:	total: 13.6s	remaining: 207ms
# 197:	total: 13.7s	remaining: 138ms
# 198:	total: 13.8s	remaining: 69.4ms
# 199:	total: 14s	remaining: 0us
# 0:	total: 172ms	remaining: 34.2s
# 1:	total: 306ms	remaining: 30.3s
# 2:	total: 447ms	remaining: 29.4s
# 3:	total: 592ms	remaining: 29s
# 4:	total: 743ms	remaining: 29s
# 5:	total: 882ms	remaining: 28.5s
# 6:	total: 1.03s	remaining: 28.4s
# 7:	total: 1.17s	remaining: 28.2s
# 8:	total: 1.32s	remaining: 28.1s
# 9:	total: 1.47s	remaining: 27.9s
# 10:	total: 1.62s	remaining: 27.9s
# 11:	total: 1.76s	remaining: 27.6s
# 12:	total: 1.88s	remaining: 27s
# 13:	total: 1.98s	remaining: 26.4s
# 14:	total: 2.13s	remaining: 26.3s
# 15:	total: 2.29s	remaining: 26.3s
# 16:	total: 2.42s	remaining: 26.1s
# 17:	total: 2.55s	remaining: 25.8s
# 18:	total: 2.7s	remaining: 25.7s
# 19:	total: 2.84s	remaining: 25.6s
# 20:	total: 3.02s	remaining: 25.7s
# 21:	total: 3.16s	remaining: 25.5s
# 22:	total: 3.29s	remaining: 25.3s
# 23:	total: 3.43s	remaining: 25.2s
# 24:	total: 3.58s	remaining: 25s
# 25:	total: 3.71s	remaining: 24.8s
# 26:	total: 3.86s	remaining: 24.8s
# 27:	total: 3.98s	remaining: 24.5s
# 28:	total: 4.13s	remaining: 24.3s
# 29:	total: 4.27s	remaining: 24.2s
# 30:	total: 4.42s	remaining: 24.1s
# 31:	total: 4.55s	remaining: 23.9s
# 32:	total: 4.71s	remaining: 23.9s
# 33:	total: 4.84s	remaining: 23.6s
# 34:	total: 5s	remaining: 23.6s
# 35:	total: 5.19s	remaining: 23.6s
# 36:	total: 5.33s	remaining: 23.5s
# 37:	total: 5.49s	remaining: 23.4s
# 38:	total: 5.63s	remaining: 23.2s
# 39:	total: 5.72s	remaining: 22.9s
# 40:	total: 5.87s	remaining: 22.8s
# 41:	total: 6.01s	remaining: 22.6s
# 42:	total: 6.17s	remaining: 22.5s
# 43:	total: 6.32s	remaining: 22.4s
# 44:	total: 6.48s	remaining: 22.3s
# 45:	total: 6.61s	remaining: 22.1s
# 46:	total: 6.76s	remaining: 22s
# 47:	total: 6.91s	remaining: 21.9s
# 48:	total: 7.06s	remaining: 21.8s
# 49:	total: 7.23s	remaining: 21.7s
# 50:	total: 7.37s	remaining: 21.5s
# 51:	total: 7.5s	remaining: 21.4s
# 52:	total: 7.66s	remaining: 21.2s
# 53:	total: 7.79s	remaining: 21.1s
# 54:	total: 7.94s	remaining: 20.9s
# 55:	total: 8.08s	remaining: 20.8s
# 56:	total: 8.23s	remaining: 20.6s
# 57:	total: 8.36s	remaining: 20.5s
# 58:	total: 8.5s	remaining: 20.3s
# 59:	total: 8.64s	remaining: 20.2s
# 60:	total: 8.79s	remaining: 20s
# 61:	total: 8.91s	remaining: 19.8s
# 62:	total: 9.08s	remaining: 19.7s
# 63:	total: 9.23s	remaining: 19.6s
# 64:	total: 9.37s	remaining: 19.5s
# 65:	total: 9.53s	remaining: 19.3s
# 66:	total: 9.68s	remaining: 19.2s
# 67:	total: 9.81s	remaining: 19s
# 68:	total: 9.97s	remaining: 18.9s
# 69:	total: 10.1s	remaining: 18.8s
# 70:	total: 10.3s	remaining: 18.6s
# 71:	total: 10.4s	remaining: 18.5s
# 72:	total: 10.5s	remaining: 18.3s
# 73:	total: 10.7s	remaining: 18.2s
# 74:	total: 10.8s	remaining: 18.1s
# 75:	total: 11s	remaining: 17.9s
# 76:	total: 11.1s	remaining: 17.8s
# 77:	total: 11.3s	remaining: 17.6s
# 78:	total: 11.4s	remaining: 17.5s
# 79:	total: 11.6s	remaining: 17.4s
# 80:	total: 11.7s	remaining: 17.2s
# 81:	total: 11.9s	remaining: 17.1s
# 82:	total: 12s	remaining: 16.9s
# 83:	total: 12.1s	remaining: 16.8s
# 84:	total: 12.3s	remaining: 16.6s
# 85:	total: 12.4s	remaining: 16.5s
# 86:	total: 12.6s	remaining: 16.3s
# 87:	total: 12.7s	remaining: 16.2s
# 88:	total: 12.9s	remaining: 16.1s
# 89:	total: 13s	remaining: 15.9s
# 90:	total: 13.1s	remaining: 15.7s
# 91:	total: 13.2s	remaining: 15.5s
# 92:	total: 13.3s	remaining: 15.3s
# 93:	total: 13.3s	remaining: 15s
# 94:	total: 13.4s	remaining: 14.8s
# 95:	total: 13.5s	remaining: 14.6s
# 96:	total: 13.5s	remaining: 14.4s
# 97:	total: 13.6s	remaining: 14.1s
# 98:	total: 13.6s	remaining: 13.9s
# 99:	total: 13.7s	remaining: 13.7s
# 100:	total: 13.8s	remaining: 13.5s
# 101:	total: 13.8s	remaining: 13.3s
# 102:	total: 13.9s	remaining: 13.1s
# 103:	total: 14s	remaining: 12.9s
# 104:	total: 14s	remaining: 12.7s
# 105:	total: 14.1s	remaining: 12.5s
# 106:	total: 14.1s	remaining: 12.3s
# 107:	total: 14.2s	remaining: 12.1s
# 108:	total: 14.3s	remaining: 11.9s
# 109:	total: 14.3s	remaining: 11.7s
# 110:	total: 14.4s	remaining: 11.6s
# 111:	total: 14.5s	remaining: 11.4s
# 112:	total: 14.5s	remaining: 11.2s
# 113:	total: 14.6s	remaining: 11s
# 114:	total: 14.6s	remaining: 10.8s
# 115:	total: 14.7s	remaining: 10.6s
# 116:	total: 14.7s	remaining: 10.5s
# 117:	total: 14.8s	remaining: 10.3s
# 118:	total: 14.9s	remaining: 10.1s
# 119:	total: 14.9s	remaining: 9.95s
# 120:	total: 15s	remaining: 9.79s
# 121:	total: 15s	remaining: 9.62s
# 122:	total: 15.1s	remaining: 9.46s
# 123:	total: 15.2s	remaining: 9.3s
# 124:	total: 15.2s	remaining: 9.14s
# 125:	total: 15.3s	remaining: 8.99s
# 126:	total: 15.4s	remaining: 8.83s
# 127:	total: 15.4s	remaining: 8.67s
# 128:	total: 15.5s	remaining: 8.52s
# 129:	total: 15.5s	remaining: 8.37s
# 130:	total: 15.6s	remaining: 8.22s
# 131:	total: 15.7s	remaining: 8.07s
# 132:	total: 15.7s	remaining: 7.92s
# 133:	total: 15.8s	remaining: 7.78s
# 134:	total: 15.8s	remaining: 7.63s
# 135:	total: 15.9s	remaining: 7.48s
# 136:	total: 16s	remaining: 7.34s
# 137:	total: 16s	remaining: 7.2s
# 138:	total: 16.1s	remaining: 7.06s
# 139:	total: 16.1s	remaining: 6.92s
# 140:	total: 16.2s	remaining: 6.79s
# 141:	total: 16.3s	remaining: 6.65s
# 142:	total: 16.3s	remaining: 6.51s
# 143:	total: 16.4s	remaining: 6.38s
# 144:	total: 16.5s	remaining: 6.24s
# 145:	total: 16.5s	remaining: 6.11s
# 146:	total: 16.6s	remaining: 5.97s
# 147:	total: 16.6s	remaining: 5.84s
# 148:	total: 16.7s	remaining: 5.71s
# 149:	total: 16.7s	remaining: 5.58s
# 150:	total: 16.8s	remaining: 5.45s
# 151:	total: 16.9s	remaining: 5.33s
# 152:	total: 16.9s	remaining: 5.2s
# 153:	total: 17s	remaining: 5.07s
# 154:	total: 17s	remaining: 4.94s
# 155:	total: 17.1s	remaining: 4.82s
# 156:	total: 17.2s	remaining: 4.7s
# 157:	total: 17.2s	remaining: 4.58s
# 158:	total: 17.3s	remaining: 4.46s
# 159:	total: 17.4s	remaining: 4.34s
# 160:	total: 17.4s	remaining: 4.22s
# 161:	total: 17.5s	remaining: 4.1s
# 162:	total: 17.5s	remaining: 3.98s
# 163:	total: 17.6s	remaining: 3.86s
# 164:	total: 17.7s	remaining: 3.75s
# 165:	total: 17.7s	remaining: 3.63s
# 166:	total: 17.8s	remaining: 3.51s
# 167:	total: 17.8s	remaining: 3.39s
# 168:	total: 17.9s	remaining: 3.28s
# 169:	total: 18s	remaining: 3.17s
# 170:	total: 18s	remaining: 3.06s
# 171:	total: 18.1s	remaining: 2.94s
# 172:	total: 18.1s	remaining: 2.83s
# 173:	total: 18.2s	remaining: 2.72s
# 174:	total: 18.3s	remaining: 2.61s
# 175:	total: 18.3s	remaining: 2.5s
# 176:	total: 18.4s	remaining: 2.39s
# 177:	total: 18.5s	remaining: 2.28s
# 178:	total: 18.5s	remaining: 2.17s
# 179:	total: 18.6s	remaining: 2.06s
# 180:	total: 18.6s	remaining: 1.96s
# 181:	total: 18.7s	remaining: 1.85s
# 182:	total: 18.8s	remaining: 1.74s
# 183:	total: 18.8s	remaining: 1.64s
# 184:	total: 18.9s	remaining: 1.53s
# 185:	total: 18.9s	remaining: 1.43s
# 186:	total: 19s	remaining: 1.32s
# 187:	total: 19.1s	remaining: 1.22s
# 188:	total: 19.1s	remaining: 1.11s
# 189:	total: 19.2s	remaining: 1.01s
# 190:	total: 19.2s	remaining: 907ms
# 191:	total: 19.3s	remaining: 805ms
# 192:	total: 19.4s	remaining: 702ms
# 193:	total: 19.4s	remaining: 601ms
# 194:	total: 19.5s	remaining: 500ms
# 195:	total: 19.5s	remaining: 399ms
# 196:	total: 19.6s	remaining: 299ms
# 197:	total: 19.7s	remaining: 199ms
# 198:	total: 19.7s	remaining: 99.1ms
# 199:	total: 19.8s	remaining: 0us
# 0:	total: 71ms	remaining: 14.1s
# 1:	total: 131ms	remaining: 12.9s
# 2:	total: 195ms	remaining: 12.8s
# 3:	total: 261ms	remaining: 12.8s
# 4:	total: 330ms	remaining: 12.9s
# 5:	total: 391ms	remaining: 12.6s
# 6:	total: 449ms	remaining: 12.4s
# 7:	total: 515ms	remaining: 12.4s
# 8:	total: 580ms	remaining: 12.3s
# 9:	total: 639ms	remaining: 12.2s
# 10:	total: 699ms	remaining: 12s
# 11:	total: 756ms	remaining: 11.8s
# 12:	total: 823ms	remaining: 11.8s
# 13:	total: 898ms	remaining: 11.9s
# 14:	total: 975ms	remaining: 12s
# 15:	total: 1.05s	remaining: 12.1s
# 16:	total: 1.11s	remaining: 11.9s
# 17:	total: 1.18s	remaining: 11.9s
# 18:	total: 1.23s	remaining: 11.8s
# 19:	total: 1.31s	remaining: 11.8s
# 20:	total: 1.37s	remaining: 11.7s
# 21:	total: 1.42s	remaining: 11.5s
# 22:	total: 1.48s	remaining: 11.4s
# 23:	total: 1.56s	remaining: 11.4s
# 24:	total: 1.61s	remaining: 11.3s
# 25:	total: 1.7s	remaining: 11.3s
# 26:	total: 1.8s	remaining: 11.5s
# 27:	total: 1.89s	remaining: 11.6s
# 28:	total: 2s	remaining: 11.8s
# 29:	total: 2.09s	remaining: 11.8s
# 30:	total: 2.19s	remaining: 11.9s
# 31:	total: 2.31s	remaining: 12.1s
# 32:	total: 2.42s	remaining: 12.2s
# 33:	total: 2.53s	remaining: 12.3s
# 34:	total: 2.64s	remaining: 12.5s
# 35:	total: 2.77s	remaining: 12.6s
# 36:	total: 2.88s	remaining: 12.7s
# 37:	total: 3s	remaining: 12.8s
# 38:	total: 3.08s	remaining: 12.7s
# 39:	total: 3.2s	remaining: 12.8s
# 40:	total: 3.3s	remaining: 12.8s
# 41:	total: 3.4s	remaining: 12.8s
# 42:	total: 3.53s	remaining: 12.9s
# 43:	total: 3.67s	remaining: 13s
# 44:	total: 3.78s	remaining: 13s
# 45:	total: 3.88s	remaining: 13s
# 46:	total: 4.02s	remaining: 13.1s
# 47:	total: 4.15s	remaining: 13.1s
# 48:	total: 4.27s	remaining: 13.2s
# 49:	total: 4.38s	remaining: 13.2s
# 50:	total: 4.5s	remaining: 13.1s
# 51:	total: 4.59s	remaining: 13.1s
# 52:	total: 4.71s	remaining: 13.1s
# 53:	total: 4.83s	remaining: 13.1s
# 54:	total: 4.96s	remaining: 13.1s
# 55:	total: 5.08s	remaining: 13.1s
# 56:	total: 5.21s	remaining: 13.1s
# 57:	total: 5.34s	remaining: 13.1s
# 58:	total: 5.49s	remaining: 13.1s
# 59:	total: 5.62s	remaining: 13.1s
# 60:	total: 5.79s	remaining: 13.2s
# 61:	total: 5.94s	remaining: 13.2s
# 62:	total: 6.06s	remaining: 13.2s
# 63:	total: 6.19s	remaining: 13.2s
# 64:	total: 6.33s	remaining: 13.2s
# 65:	total: 6.5s	remaining: 13.2s
# 66:	total: 6.64s	remaining: 13.2s
# 67:	total: 6.79s	remaining: 13.2s
# 68:	total: 6.94s	remaining: 13.2s
# 69:	total: 7.11s	remaining: 13.2s
# 70:	total: 7.26s	remaining: 13.2s
# 71:	total: 7.39s	remaining: 13.1s
# 72:	total: 7.52s	remaining: 13.1s
# 73:	total: 7.67s	remaining: 13.1s
# 74:	total: 7.8s	remaining: 13s
# 75:	total: 7.93s	remaining: 12.9s
# 76:	total: 8.09s	remaining: 12.9s
# 77:	total: 8.23s	remaining: 12.9s
# 78:	total: 8.38s	remaining: 12.8s
# 79:	total: 8.5s	remaining: 12.7s
# 80:	total: 8.6s	remaining: 12.6s
# 81:	total: 8.74s	remaining: 12.6s
# 82:	total: 8.88s	remaining: 12.5s
# 83:	total: 9.03s	remaining: 12.5s
# 84:	total: 9.17s	remaining: 12.4s
# 85:	total: 9.31s	remaining: 12.3s
# 86:	total: 9.44s	remaining: 12.3s
# 87:	total: 9.57s	remaining: 12.2s
# 88:	total: 9.71s	remaining: 12.1s
# 89:	total: 9.84s	remaining: 12s
# 90:	total: 9.97s	remaining: 11.9s
# 91:	total: 10.1s	remaining: 11.9s
# 92:	total: 10.3s	remaining: 11.8s
# 93:	total: 10.4s	remaining: 11.8s
# 94:	total: 10.6s	remaining: 11.7s
# 95:	total: 10.7s	remaining: 11.6s
# 96:	total: 10.9s	remaining: 11.5s
# 97:	total: 11s	remaining: 11.5s
# 98:	total: 11.2s	remaining: 11.4s
# 99:	total: 11.3s	remaining: 11.3s
# 100:	total: 11.4s	remaining: 11.2s
# 101:	total: 11.6s	remaining: 11.1s
# 102:	total: 11.7s	remaining: 11s
# 103:	total: 11.8s	remaining: 10.9s
# 104:	total: 11.9s	remaining: 10.8s
# 105:	total: 12s	remaining: 10.7s
# 106:	total: 12.2s	remaining: 10.6s
# 107:	total: 12.3s	remaining: 10.5s
# 108:	total: 12.5s	remaining: 10.4s
# 109:	total: 12.6s	remaining: 10.3s
# 110:	total: 12.8s	remaining: 10.2s
# 111:	total: 12.9s	remaining: 10.1s
# 112:	total: 13s	remaining: 10s
# 113:	total: 13.2s	remaining: 9.93s
# 114:	total: 13.3s	remaining: 9.84s
# 115:	total: 13.5s	remaining: 9.74s
# 116:	total: 13.6s	remaining: 9.65s
# 117:	total: 13.8s	remaining: 9.56s
# 118:	total: 13.9s	remaining: 9.47s
# 119:	total: 14.1s	remaining: 9.4s
# 120:	total: 14.2s	remaining: 9.3s
# 121:	total: 14.4s	remaining: 9.2s
# 122:	total: 14.6s	remaining: 9.11s
# 123:	total: 14.7s	remaining: 9s
# 124:	total: 14.8s	remaining: 8.91s
# 125:	total: 15s	remaining: 8.81s
# 126:	total: 15.1s	remaining: 8.7s
# 127:	total: 15.2s	remaining: 8.58s
# 128:	total: 15.4s	remaining: 8.47s
# 129:	total: 15.5s	remaining: 8.36s
# 130:	total: 15.7s	remaining: 8.26s
# 131:	total: 15.8s	remaining: 8.16s
# 132:	total: 16s	remaining: 8.05s
# 133:	total: 16.2s	remaining: 7.96s
# 134:	total: 16.3s	remaining: 7.85s
# 135:	total: 16.5s	remaining: 7.75s
# 136:	total: 16.6s	remaining: 7.63s
# 137:	total: 16.7s	remaining: 7.52s
# 138:	total: 16.9s	remaining: 7.42s
# 139:	total: 17.1s	remaining: 7.31s
# 140:	total: 17.2s	remaining: 7.19s
# 141:	total: 17.3s	remaining: 7.08s
# 142:	total: 17.5s	remaining: 6.96s
# 143:	total: 17.6s	remaining: 6.84s
# 144:	total: 17.7s	remaining: 6.72s
# 145:	total: 17.9s	remaining: 6.61s
# 146:	total: 18s	remaining: 6.5s
# 147:	total: 18.2s	remaining: 6.38s
# 148:	total: 18.3s	remaining: 6.27s
# 149:	total: 18.5s	remaining: 6.15s
# 150:	total: 18.6s	remaining: 6.04s
# 151:	total: 18.8s	remaining: 5.92s
# 152:	total: 18.9s	remaining: 5.81s
# 153:	total: 19s	remaining: 5.69s
# 154:	total: 19.2s	remaining: 5.58s
# 155:	total: 19.4s	remaining: 5.46s
# 156:	total: 19.5s	remaining: 5.33s
# 157:	total: 19.6s	remaining: 5.22s
# 158:	total: 19.8s	remaining: 5.1s
# 159:	total: 19.9s	remaining: 4.97s
# 160:	total: 20s	remaining: 4.85s
# 161:	total: 20.2s	remaining: 4.73s
# 162:	total: 20.2s	remaining: 4.59s
# 163:	total: 20.4s	remaining: 4.47s
# 164:	total: 20.5s	remaining: 4.36s
# 165:	total: 20.7s	remaining: 4.24s
# 166:	total: 20.8s	remaining: 4.12s
# 167:	total: 21s	remaining: 4s
# 168:	total: 21.1s	remaining: 3.87s
# 169:	total: 21.3s	remaining: 3.75s
# 170:	total: 21.4s	remaining: 3.63s
# 171:	total: 21.6s	remaining: 3.51s
# 172:	total: 21.7s	remaining: 3.39s
# 173:	total: 21.9s	remaining: 3.27s
# 174:	total: 21.9s	remaining: 3.13s
# 175:	total: 22s	remaining: 3s
# 176:	total: 22s	remaining: 2.86s
# 177:	total: 22.1s	remaining: 2.73s
# 178:	total: 22.1s	remaining: 2.6s
# 179:	total: 22.2s	remaining: 2.47s
# 180:	total: 22.3s	remaining: 2.34s
# 181:	total: 22.3s	remaining: 2.21s
# 182:	total: 22.4s	remaining: 2.08s
# 183:	total: 22.4s	remaining: 1.95s
# 184:	total: 22.5s	remaining: 1.82s
# 185:	total: 22.6s	remaining: 1.7s
# 186:	total: 22.6s	remaining: 1.57s
# 187:	total: 22.7s	remaining: 1.45s
# 188:	total: 22.8s	remaining: 1.32s
# 189:	total: 22.9s	remaining: 1.2s
# 190:	total: 22.9s	remaining: 1.08s
# 191:	total: 23s	remaining: 957ms
# 192:	total: 23s	remaining: 835ms
# 193:	total: 23.1s	remaining: 714ms
# 194:	total: 23.1s	remaining: 593ms
# 195:	total: 23.2s	remaining: 473ms
# 196:	total: 23.3s	remaining: 354ms
# 197:	total: 23.3s	remaining: 236ms
# 198:	total: 23.4s	remaining: 118ms
# 199:	total: 23.4s	remaining: 0us
# XG-CV: 0.2597362771878248
# ET-CV: 0.26296502347137407
# RF-CV: 0.2629856213006646
# RF-CV: 0.3309547098229581
# (307511, 4),(48744, 4)

# %% [markdown]
# It is just a simple starter. It can really be improved.
# **First idea : increase the number of iterations in XGBOOST and number of trees in RandomForest & ExtraTrees**
#
# The aim of this kernel was not to take care of data cleaning but focus on ensembling methods.
#
#
# I am having massive overfitting - are you having the same problem? I feel like it is because of class imbalance. What do you think?
# I think the overfitting part is mainly due to the second layer of the ensembling. Removing the xgb part to put some logistic regression could be way better. I plan to do it soon.
#
#
# Looks like the author didn't end up using skew looking at the code. However, there is a large imbalance in the y_train values - about 10:1.
# Yes exactly, I didn't use skew here but you could imagine using it to transform to log some features

# %%
# pandas and numpy for data manipulation
import pandas as pd
import numpy as np

# matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
import seaborn as sns

# Suppress warnings from pandas
import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
